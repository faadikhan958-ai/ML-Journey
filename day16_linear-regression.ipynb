# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = {
    'size': [200, 400, 500, 900, 1000, 1200],
    'bedroom': [1, 2, 2, 3, 2, 5],
    'price': [20, 40, 50, 90, 100, 120]
}
df = pd.DataFrame(data)

X = df[['size', 'bedroom']]
Y = df['price']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(X_train, Y_train)

predictions = model.predict(X_test)
print("Actual:", Y_test.values)
print("Predicted:", predictions)
# Out:
# Actual: [20 40]
# Predicted: [20. 40.]

# %%
data = {
    'size': [1000, 2000, 5000, 9000, 10000, 12000],
    'bedroom': [1, 2, 2, 3, 2, 5],
    'price': [20, 40, 50, 90, 100, 120]
}
df = pd.DataFrame(data)
X = df[['size', 'bedroom']]
Y = df['price']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(X_train, Y_train)
predictions = model.predict(X_test)
print("Actual:", Y_test.values)
print("Predicted:", predictions)
# Out:
# Actual: [20 40]
# Predicted: [10. 20.]

# %%
#slope and intercept
print('slope(m):',model.coef_)
print('intercept:',model.intercept_)
# Out:
# slope(m): [  0.4        106.66666667]
# intercept: -105.0

# %%
#Accuracy
score=model.score(x_test,y_test)
print("Accuracy",score)
# Out:
# Accuracy -5.338222222222222

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
data2={

    'study_hours':[1,2,3,4,5,6,7],
    'marks':[50,60,70,80,90,100,110]
}
df2=pd.DataFrame(data2)
x2=df2[['study_hours']]
y2=df2['marks']
x2_train,x2_test,y2_train,y2_test=train_test_split(x2,y2,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(x2_train,y2_train)
predictions=model.predict(x2_test)
print("actual:",y2_test.values)
print("predicted:",predictions)
# Out:
# actual: [50 60]
# predicted: [50. 60.]

# %%
#slope and intercept
print("slope(m):",model.coef_)
print("intercept(c):",model.intercept_)
# Out:
# slope(m): [10.]
# intercept(c): 40.00000000000001

# %%
score=model.score(x2_test,y2_test)
print("accuracy:",score)
# Out:
# accuracy: 1.0

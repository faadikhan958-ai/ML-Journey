# %%
import numpy as np
arr=np.array([10,20,30,40,50,60])
print(len(arr))
print(arr.max())
print(arr.min())
print(arr.sum())
print(arr.std())
print(arr.mean())
# Out:
# 6
# 60
# 10
# 210
# 17.07825127659933
# 35.0

# %%
import numpy as np
print("setup successful")
# Out:
# setup successful

# %%
import numpy as np
a=np.array([1,2,3,4,5])
b=np.array([6,7,8,9,10])
print(a+b)
print(a*b)
# Out:
# [ 7  9 11 13 15]
# [ 6 14 24 36 50]

# %%
import numpy as np
arr=np.array([10,20,30,40,50,60])
print(arr[0])
print(arr [-1])
print(arr[4:6])
# Out:
# 10
# 60
# [50 60]

# %%
import numpy as np
a=np.array([3,5,7,9])
b=np.array([2,3,4,5])
r=np.dot(a,b)
print(r)
# Out:
# 94

# %%
import numpy as np
arr=np.array([10,20,30,40,50,60])
reshaped=arr.reshape(2,3)
print(reshaped)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
a=np.array([[1,2],[3,4]])
b=np.array([[5,6],[7,8]])
a @ b
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
import numpy as np
arr=np.array([10,20,30,40])
print(arr+10)
# Out:
# [20 30 40 50]

# %%
x=np.array([[3,4],[3,7]])
y=np.array([[4,6],[7,9]])
np.matmul(x,y)
# Out:
# array([[40, 54],
#        [61, 81]])

# %%
random_arr=np.random.radint(1,50,size=5)
print(random_arr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 random_arr=np.random.radint(1,50,size=5)
#       2 print(random_arr)
#
# AttributeError: module 'numpy.random' has no attribute 'radint'

# %%
random_arr=np.random.randint(1,40, size=3)
print(random_arr)
# Out:
# [22  1 12]

# %%
random_arr=np.random.randint(1,100, size=5)
print(random_arr)
# Out:
# [65 41 74 98 10]

# %%
a=np.random.randint(1,10,size=1)
print(a)
# Out:
# [3]

# %%
num=[3,5,7,10,12]
print(num[0])
print(len(num))
print(min(num))
print(max(num))
print(sum(num))
num.append(5)
print (num)
# Out:
# 3
# 5
# 3
# 12
# 37
# [3, 5, 7, 10, 12, 5]

# %%
num=[3,5,7,8]
num.append(15)
print(num)
# Out:
# [3, 5, 7, 8, 15]

# %%
A=np.array([[11,22,33],
            [44,55,66],
            [77,88,99]])
print(A.T)
# Out:
# [[11 44 77]
#  [22 55 88]
#  [33 66 99]]

# %%
a=np.array([2,3,4])
b=np.array([3,6,9])
c=np.dot(a,b)
print(c)
# Out:
# 60

# %%
a=np.array([1,3])
b=np.array([7,9])
a@b
# Out:
# np.int64(34)

# %%
a=np.array([1,5,6])
b=np.array([4,6,7])
r=np.matmul(a,b)
print(r)
# Out:
# 76

# %%
A=np.array([[1,3,4,5],
            [2,3,4,5],
            [4,6,7,8]])
print(A.T)
# Out:
# [[1 2 4]
#  [3 3 6]
#  [4 4 7]
#  [5 5 8]]

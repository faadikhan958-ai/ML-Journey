# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
data={
    'age':[12,14,54,67,87,65,32,23],
    'fare':[32,43,2,5,64,7,8,98],
    'survived':[0,1,1,0,1,0,1,0]
}
df=pd.DataFrame(data)
X=df[['age','fare']]
Y=df[['survived']]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

print("training data size",len(X_train))
print("testing data size",len(X_test))

print(X_train)
print(X_test)
# Out:
# training data size 6
# testing data size 2
#    age  fare
# 0   12    32
# 5   65     7
# 6   32     8
# 2   54     2
# 4   87    64
# 3   67     5
#    age  fare
# 7   23    98
# 1   14    43

# %%
import seaborn as sns
titanic=sns.load_dataset('titanic')
titanic['age']=titanic['age'].fillna(titanic['age'].mean())
x=titanic[['fare','age','pclass']]
y=titanic[['survived']]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
print(x_train)
print(x_test)
# Out:
#          fare        age  pclass
# 445   81.8583   4.000000       1
# 650    7.8958  29.699118       3
# 172   11.1333   1.000000       3
# 450   27.7500  36.000000       2
# 314   26.2500  43.000000       2
# ..        ...        ...     ...
# 106    7.6500  21.000000       3
# 270   31.0000  29.699118       1
# 860   14.1083  41.000000       3
# 435  120.0000  14.000000       1
# 102   77.2875  21.000000       1
#
# [623 rows x 3 columns]
#         fare        age  pclass
# 709  15.2458  29.699118       3
# 439  10.5000  31.000000       2
# 840   7.9250  20.000000       3
# 720  33.0000   6.000000       2
# 39   11.2417  14.000000       3
# ..       ...        ...     ...
# 821   8.6625  27.000000       3
# 633   0.0000  29.699118       1
# 456  26.5500  65.000000       1
# 500   8.6625  17.000000       3
# 430  26.5500  28.000000       1
#
# [268 rows x 3 columns]
